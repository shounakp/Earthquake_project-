# %% [markdown]
# # Worldwide Earthquake Events API - Silver Layer Processing

# %%
from pyspark.sql.functions import col
from pyspark.sql.types import TimestampType
# Out:
# StatementMeta(, 2029dff4-245d-49f0-85e0-64bb55013aeb, 15, Finished, Available, Finished)

# %%
# df now is a Spark DataFrame containing JSON data
raw_df = spark.read.option("multiline", "true").json(f"Files/{start_date}_earthquake_data.json")
# Out:
# StatementMeta(, 2029dff4-245d-49f0-85e0-64bb55013aeb, 17, Finished, Available, Finished)

# %%
from pyspark.sql.functions import col

df = raw_df.select(
    'id',
    col('geometry.coordinates')[0].alias('longitude'),
    col('geometry.coordinates')[1].alias('latitude'),
    col('geometry.coordinates')[2].alias('elevation'),
    col('properties.title').alias('title'),
    col('properties.place').alias('place_description'),
    col('properties.sig').alias('sig'),
    col('properties.mag').alias('mag'),
    col('properties.magType').alias('magType'),
    col('properties.time').alias('time'),
    col('properties.updated').alias('updated')
)
# Out:
# StatementMeta(, 2029dff4-245d-49f0-85e0-64bb55013aeb, 19, Finished, Available, Finished)

# %%
# Convert 'time' and 'updated' columns from milliseconds to timestamp format for clearer datetime representation.
df = df.\
    withColumn('time', col('time')/1000).\
    withColumn('updated', col('updated')/1000).\
    withColumn('time', col('time').cast(TimestampType())).\
    withColumn('updated', col('updated').cast(TimestampType()))
# Out:
# StatementMeta(, 2029dff4-245d-49f0-85e0-64bb55013aeb, 21, Finished, Available, Finished)

# %%
# appending the data to the gold table
df.write.mode('append').saveAsTable('earthquake_events_silver')
# Out:
# StatementMeta(, 2029dff4-245d-49f0-85e0-64bb55013aeb, 23, Finished, Available, Finished)
